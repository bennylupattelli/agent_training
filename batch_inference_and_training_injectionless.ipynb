# %%
from trainer_and_simulator_functions import sequential_runs
from pathlib import Path

# %% [markdown]
# ### Sequential training runs without yaml injection or simulation functionality

# %% [markdown]
# #### Competitive

# %%
sequential_runs(
        in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml").expanduser(),
        run_dir=Path("~/Unity/Octagon").expanduser(),
        gamma=0.99,
        sp=1e-3,
        behaviour_name="OctagonAgentSocial",
        unity_build=Path("/home/tom/Unity/Octagon/builds/build_260624_03_social.x86_64"),
        base_run_id="260624",
        device="cuda:0",
        n_models=10,
        run_id_offset=30,
        simulate=False,
        n_envs=16,
        seed=17,
        extra_args=["--resume"]
)

# Seed 17 used for all runs since at least 2606
# Out:
# patched yaml for run 260624_0031 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0031 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0031
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0031/OctagonAgentSocial.
# [INFO] Resuming training from step 4000032.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0031/OctagonAgentSocial/OctagonAgentSocial-4000032.onnx
# [INFO] Copied results/260624_0031/OctagonAgentSocial/OctagonAgentSocial-4000032.onnx to results/260624_0031/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0032 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0032 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0032
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0032/OctagonAgentSocial.
# [INFO] Resuming training from step 4000059.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0032/OctagonAgentSocial/OctagonAgentSocial-4000059.onnx
# [INFO] Copied results/260624_0032/OctagonAgentSocial/OctagonAgentSocial-4000059.onnx to results/260624_0032/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0033 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0033 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0033
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0033/OctagonAgentSocial.
# [INFO] Resuming training from step 4000024.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0033/OctagonAgentSocial/OctagonAgentSocial-4000024.onnx
# [INFO] Copied results/260624_0033/OctagonAgentSocial/OctagonAgentSocial-4000024.onnx to results/260624_0033/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0034 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0034 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0034
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0034/OctagonAgentSocial.
# [INFO] Resuming training from step 4000014.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0034/OctagonAgentSocial/OctagonAgentSocial-4000014.onnx
# [INFO] Copied results/260624_0034/OctagonAgentSocial/OctagonAgentSocial-4000014.onnx to results/260624_0034/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0035 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0035 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0035
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0035/OctagonAgentSocial.
# [INFO] Resuming training from step 4000018.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0035/OctagonAgentSocial/OctagonAgentSocial-4000018.onnx
# [INFO] Copied results/260624_0035/OctagonAgentSocial/OctagonAgentSocial-4000018.onnx to results/260624_0035/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0036 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0036 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0036
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0036/OctagonAgentSocial.
# [INFO] Resuming training from step 4000002.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0036/OctagonAgentSocial/OctagonAgentSocial-4000002.onnx
# [INFO] Copied results/260624_0036/OctagonAgentSocial/OctagonAgentSocial-4000002.onnx to results/260624_0036/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0037 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0037 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0037
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0037/OctagonAgentSocial.
# [INFO] Resuming training from step 4000042.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0037/OctagonAgentSocial/OctagonAgentSocial-4000042.onnx
# [INFO] Copied results/260624_0037/OctagonAgentSocial/OctagonAgentSocial-4000042.onnx to results/260624_0037/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0038 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0038 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0038
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Connected new brain: OctagonAgentSocial?team=0
# [INFO] Connected new brain: OctagonAgentSocial?team=1
# [INFO] Hyperparameters for behavior name OctagonAgentSocial:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	20480
# 	  learning_rate:	0.00015
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	40
# 	even_checkpoints:	False
# 	max_steps:	4000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:
# 	  save_steps:	150000
# 	  team_change:	750000
# 	  swap_steps:	150000
# 	  window:	8
# 	  play_against_latest_model_ratio:	0.5
# 	  initial_elo:	1200.0
# 	behavioral_cloning:	None
# [INFO] Resuming from results/260624_0038/OctagonAgentSocial.
# [INFO] Resuming training from step 4000022.
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260624_0038/OctagonAgentSocial/OctagonAgentSocial-4000022.onnx
# [INFO] Copied results/260624_0038/OctagonAgentSocial/OctagonAgentSocial-4000022.onnx to results/260624_0038/OctagonAgentSocial.onnx.
# patched yaml for run 260624_0039 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# launching training for run 260624_0039 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml
# Using seed: 17 for training run 260624_0039
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# Traceback (most recent call last):
#   File "/home/tom/miniconda3/envs/mlagents/bin/mlagents-learn", line 7, in <module>
#     sys.exit(main())
#   File "/home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/trainers/learn.py", line 270, in main
#     run_cli(parse_command_line())
#   File "/home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/trainers/learn.py", line 266, in run_cli
#     run_training(run_seed, options, num_areas)
#   File "/home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/trainers/learn.py", line 75, in run_training
#     validate_existing_directories(
#   File "/home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/trainers/directory_utils.py", line 32, in validate_existing_directories
#     raise UnityTrainerException(
# mlagents.trainers.exception.UnityTrainerException: Previous data from this run ID was not found. Train a new run by removing the --resume flag.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sequential_runs(
#       2         in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml").expanduser(),
#       3         run_dir=Path("~/Unity/Octagon").expanduser(),
#       4         gamma=0.99,
#       5         sp=1e-3,
#       6         behaviour_name="OctagonAgentSocial",
#       7         unity_build=Path("/home/tom/Unity/Octagon/builds/build_260624_03_social.x86_64"),
#       8         base_run_id="260624",
#       9         device="cuda:0",
#      10         n_models=10,
#      11         run_id_offset=30,
#      12         simulate=False,
#      13         n_envs=16,
#      14         seed=17,
#      15         extra_args=["--resume"]
#      16 )
#      18 # Seed 17 used for all runs since at least 2606
#
# File ~/repos/agent_training/trainer_and_simulator_functions.py:437, in sequential_runs(in_yaml, run_dir, yaml_injection, gamma, sp, behaviour_name, unity_build, base_run_id, device, n_models, run_id_offset, simulate, n_envs, n_steps, seed, extra_args)
#     435 print(f"launching training for run {run_id} with config {patched_yaml_path}")
#     436 # this function launches one training run with the specified yaml file and Unity environment build
# --> 437 launch_training(
#     438     patched_yaml=patched_yaml_path,
#     439     unity_env_path=unity_build,
#     440     run_id=run_id,
#     441     torch_device=device,
#     442     num_envs=n_envs,
#     443     base_port=train_port,
#     444     seed=seed,
#     445     run_dir=run_dir,
#     446     extra_args=extra_args
#     447 )
#     449 if simulate == True:
#     450     print(f"launching inference for run {run_id}")
#
# File ~/repos/agent_training/trainer_and_simulator_functions.py:193, in launch_training(patched_yaml, unity_env_path, run_id, torch_device, num_envs, base_port, seed, extra_args, run_dir)
#     191 p.wait()  # wait for the process to complete
#     192 if p.returncode != 0:
# --> 193     raise subprocess.CalledProcessError(p.returncode, cmd)
#
# CalledProcessError: Command '['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfigHigherRnd.yaml', '--env', '/home/tom/Unity/Octagon/builds/build_260624_03_social.x86_64', '--torch-device', 'cuda:0', '--num-envs', '16', '--no-graphics', '--run-id', '260624_0039', '--base-port', '5165', '--seed', '17', '--resume']' returned non-zero exit status 1.

# %% [markdown]
# #### Solo

# %%
sequential_runs(
        # in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfig.yaml").expanduser(),
        # in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml").expanduser(),
        # in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumSoloConfig.yaml").expanduser(),
        in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumAndHigherRndSoloConfig.yaml").expanduser(),

        
        run_dir=Path("~/Unity/Octagon").expanduser(),
        gamma=0.99,
        sp=1e-3,
        behaviour_name="OctagonAgentSolo",
        unity_build=Path("/home/tom/Unity/Octagon/builds/build_260618_01_solo.x86_64"),
        base_run_id="260518",
        device="cuda:0",
        n_models=10,
        run_id_offset=6,
        simulate=False,
        n_envs=16,
        seed=17,
        # extra_args=["--resume"]
)

##260515
# Seed 17 used 
#1st build, normal, used for 1-10. 2nd build, lacking 180 degrees for 11-20. Curriculum config used for 21-30, higher RND normal config (0.02) used for 31-40.
# Out:
# patched yaml for run 260518_0007 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumAndHigherRndSoloConfig.yaml
# launching training for run 260518_0007 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumAndHigherRndSoloConfig.yaml
# Using seed: 17 for training run 260518_0007
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Hyperparameters for behavior name OctagonAgentSolo:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	10240
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	30
# 	even_checkpoints:	False
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# [INFO] Parameter 'sep_weight_1' is in lesson 'bias_180' and has value 'Float: value=0.2'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'bias_180' and has value 'Float: value=0.2'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'bias_180' and has value 'Float: value=0.6'.
# [INFO] OctagonAgentSolo. Step: 20000. Time Elapsed: 41.069 s. Mean Reward: -0.961. Std of Reward: 0.007. Training.
# [INFO] OctagonAgentSolo. Step: 40000. Time Elapsed: 81.152 s. Mean Reward: -0.965. Std of Reward: 0.005. Training.
# [INFO] OctagonAgentSolo. Step: 60000. Time Elapsed: 120.695 s. Mean Reward: -0.677. Std of Reward: 0.485. Training.
# [INFO] OctagonAgentSolo. Step: 80000. Time Elapsed: 160.443 s. Mean Reward: -0.473. Std of Reward: 0.552. Training.
# [INFO] OctagonAgentSolo. Step: 100000. Time Elapsed: 199.514 s. Mean Reward: -0.547. Std of Reward: 0.581. Training.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-99908.onnx
# [INFO] OctagonAgentSolo. Step: 120000. Time Elapsed: 238.231 s. Mean Reward: -0.131. Std of Reward: 0.723. Training.
# [INFO] OctagonAgentSolo. Step: 140000. Time Elapsed: 276.812 s. Mean Reward: -0.011. Std of Reward: 0.619. Training.
# [INFO] OctagonAgentSolo. Step: 160000. Time Elapsed: 316.122 s. Mean Reward: 0.090. Std of Reward: 0.581. Training.
# [INFO] OctagonAgentSolo. Step: 180000. Time Elapsed: 354.829 s. Mean Reward: 0.026. Std of Reward: 0.478. Training.
# [INFO] OctagonAgentSolo. Step: 200000. Time Elapsed: 393.940 s. Mean Reward: -0.029. Std of Reward: 0.509. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-199911.onnx
# [INFO] OctagonAgentSolo. Step: 220000. Time Elapsed: 433.062 s. Mean Reward: 0.061. Std of Reward: 0.505. Training.
# [INFO] OctagonAgentSolo. Step: 240000. Time Elapsed: 471.579 s. Mean Reward: 0.036. Std of Reward: 0.469. Training.
# [INFO] OctagonAgentSolo. Step: 260000. Time Elapsed: 509.972 s. Mean Reward: 0.042. Std of Reward: 0.489. Training.
# [INFO] OctagonAgentSolo. Step: 280000. Time Elapsed: 549.376 s. Mean Reward: -0.184. Std of Reward: 0.502. Training.
# [INFO] OctagonAgentSolo. Step: 300000. Time Elapsed: 588.307 s. Mean Reward: 0.042. Std of Reward: 0.570. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-299914.onnx
# [INFO] OctagonAgentSolo. Step: 320000. Time Elapsed: 628.283 s. Mean Reward: 0.074. Std of Reward: 0.382. Training.
# [INFO] OctagonAgentSolo. Step: 340000. Time Elapsed: 667.982 s. Mean Reward: 0.103. Std of Reward: 0.449. Training.
# [INFO] OctagonAgentSolo. Step: 360000. Time Elapsed: 707.431 s. Mean Reward: -0.057. Std of Reward: 0.490. Training.
# [INFO] OctagonAgentSolo. Step: 380000. Time Elapsed: 746.989 s. Mean Reward: 0.209. Std of Reward: 0.409. Training.
# [INFO] OctagonAgentSolo. Step: 400000. Time Elapsed: 787.617 s. Mean Reward: 0.185. Std of Reward: 0.424. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-399913.onnx
# [INFO] OctagonAgentSolo. Step: 420000. Time Elapsed: 827.264 s. Mean Reward: 0.108. Std of Reward: 0.413. Training.
# [INFO] OctagonAgentSolo. Step: 440000. Time Elapsed: 867.146 s. Mean Reward: 0.221. Std of Reward: 0.388. Training.
# [INFO] OctagonAgentSolo. Step: 460000. Time Elapsed: 907.692 s. Mean Reward: -0.032. Std of Reward: 0.402. Training.
# [INFO] OctagonAgentSolo. Step: 480000. Time Elapsed: 948.096 s. Mean Reward: 0.187. Std of Reward: 0.377. Training.
# [INFO] OctagonAgentSolo. Step: 500000. Time Elapsed: 987.812 s. Mean Reward: 0.223. Std of Reward: 0.393. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-499976.onnx
# [INFO] OctagonAgentSolo. Step: 520000. Time Elapsed: 1026.056 s. Mean Reward: 0.211. Std of Reward: 0.376. Training.
# [INFO] OctagonAgentSolo. Step: 540000. Time Elapsed: 1065.617 s. Mean Reward: 0.037. Std of Reward: 0.487. Training.
# [INFO] OctagonAgentSolo. Step: 560000. Time Elapsed: 1105.035 s. Mean Reward: -0.172. Std of Reward: 0.555. Training.
# [INFO] OctagonAgentSolo. Step: 580000. Time Elapsed: 1143.381 s. Mean Reward: -0.008. Std of Reward: 0.521. Training.
# [INFO] OctagonAgentSolo. Step: 600000. Time Elapsed: 1183.550 s. Mean Reward: 0.112. Std of Reward: 0.453. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-599979.onnx
# [INFO] Parameter 'sep_weight_1' is in lesson 'transition' and has value 'Float: value=0.35'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'transition' and has value 'Float: value=0.25'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'transition' and has value 'Float: value=0.4'.
# [INFO] OctagonAgentSolo. Step: 620000. Time Elapsed: 1223.329 s. Mean Reward: 0.175. Std of Reward: 0.374. Training.
# [INFO] OctagonAgentSolo. Step: 640000. Time Elapsed: 1261.940 s. Mean Reward: 0.328. Std of Reward: 0.359. Training.
# [INFO] OctagonAgentSolo. Step: 660000. Time Elapsed: 1301.045 s. Mean Reward: 0.286. Std of Reward: 0.363. Training.
# [INFO] OctagonAgentSolo. Step: 680000. Time Elapsed: 1339.825 s. Mean Reward: 0.284. Std of Reward: 0.378. Training.
# [INFO] OctagonAgentSolo. Step: 700000. Time Elapsed: 1378.637 s. Mean Reward: 0.283. Std of Reward: 0.420. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-699992.onnx
# [INFO] OctagonAgentSolo. Step: 720000. Time Elapsed: 1420.759 s. Mean Reward: 0.220. Std of Reward: 0.356. Training.
# [INFO] OctagonAgentSolo. Step: 740000. Time Elapsed: 1461.632 s. Mean Reward: 0.389. Std of Reward: 0.272. Training.
# [INFO] OctagonAgentSolo. Step: 760000. Time Elapsed: 1500.845 s. Mean Reward: 0.377. Std of Reward: 0.277. Training.
# [INFO] OctagonAgentSolo. Step: 780000. Time Elapsed: 1539.625 s. Mean Reward: 0.384. Std of Reward: 0.285. Training.
# [INFO] OctagonAgentSolo. Step: 800000. Time Elapsed: 1578.640 s. Mean Reward: 0.389. Std of Reward: 0.289. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-799898.onnx
# [INFO] OctagonAgentSolo. Step: 820000. Time Elapsed: 1616.428 s. Mean Reward: 0.360. Std of Reward: 0.285. Training.
# [INFO] OctagonAgentSolo. Step: 840000. Time Elapsed: 1655.180 s. Mean Reward: 0.370. Std of Reward: 0.274. Training.
# [INFO] OctagonAgentSolo. Step: 860000. Time Elapsed: 1693.997 s. Mean Reward: 0.379. Std of Reward: 0.278. Training.
# [INFO] OctagonAgentSolo. Step: 880000. Time Elapsed: 1732.885 s. Mean Reward: 0.388. Std of Reward: 0.282. Training.
# [INFO] OctagonAgentSolo. Step: 900000. Time Elapsed: 1771.539 s. Mean Reward: 0.374. Std of Reward: 0.280. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-899976.onnx
# [INFO] OctagonAgentSolo. Step: 920000. Time Elapsed: 1810.959 s. Mean Reward: 0.431. Std of Reward: 0.252. Training.
# [INFO] OctagonAgentSolo. Step: 940000. Time Elapsed: 1849.954 s. Mean Reward: 0.342. Std of Reward: 0.268. Training.
# [INFO] OctagonAgentSolo. Step: 960000. Time Elapsed: 1888.917 s. Mean Reward: 0.396. Std of Reward: 0.267. Training.
# [INFO] OctagonAgentSolo. Step: 980000. Time Elapsed: 1927.088 s. Mean Reward: 0.355. Std of Reward: 0.289. Training.
# [INFO] OctagonAgentSolo. Step: 1000000. Time Elapsed: 1965.069 s. Mean Reward: 0.450. Std of Reward: 0.236. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-999882.onnx
# [INFO] OctagonAgentSolo. Step: 1020000. Time Elapsed: 2003.737 s. Mean Reward: 0.379. Std of Reward: 0.275. Training.
# [INFO] OctagonAgentSolo. Step: 1040000. Time Elapsed: 2042.961 s. Mean Reward: 0.425. Std of Reward: 0.256. Training.
# [INFO] OctagonAgentSolo. Step: 1060000. Time Elapsed: 2082.022 s. Mean Reward: 0.407. Std of Reward: 0.271. Training.
# [INFO] OctagonAgentSolo. Step: 1080000. Time Elapsed: 2120.504 s. Mean Reward: 0.433. Std of Reward: 0.255. Training.
# [INFO] OctagonAgentSolo. Step: 1100000. Time Elapsed: 2159.714 s. Mean Reward: 0.432. Std of Reward: 0.251. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1099952.onnx
# [INFO] OctagonAgentSolo. Step: 1120000. Time Elapsed: 2198.565 s. Mean Reward: 0.396. Std of Reward: 0.252. Training.
# [INFO] OctagonAgentSolo. Step: 1140000. Time Elapsed: 2237.200 s. Mean Reward: 0.446. Std of Reward: 0.239. Training.
# [INFO] OctagonAgentSolo. Step: 1160000. Time Elapsed: 2276.645 s. Mean Reward: 0.360. Std of Reward: 0.293. Training.
# [INFO] OctagonAgentSolo. Step: 1180000. Time Elapsed: 2315.530 s. Mean Reward: 0.447. Std of Reward: 0.254. Training.
# [INFO] OctagonAgentSolo. Step: 1200000. Time Elapsed: 2353.904 s. Mean Reward: 0.397. Std of Reward: 0.258. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1199909.onnx
# [INFO] Parameter 'sep_weight_1' is in lesson 'target_distribution' and has value 'Float: value=0.5'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] OctagonAgentSolo. Step: 1220000. Time Elapsed: 2392.679 s. Mean Reward: 0.437. Std of Reward: 0.248. Training.
# [INFO] OctagonAgentSolo. Step: 1240000. Time Elapsed: 2432.253 s. Mean Reward: 0.469. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 1260000. Time Elapsed: 2471.390 s. Mean Reward: 0.500. Std of Reward: 0.187. Training.
# [INFO] OctagonAgentSolo. Step: 1280000. Time Elapsed: 2510.403 s. Mean Reward: 0.494. Std of Reward: 0.168. Training.
# [INFO] OctagonAgentSolo. Step: 1300000. Time Elapsed: 2548.767 s. Mean Reward: 0.470. Std of Reward: 0.205. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1299931.onnx
# [INFO] OctagonAgentSolo. Step: 1320000. Time Elapsed: 2587.483 s. Mean Reward: 0.453. Std of Reward: 0.222. Training.
# [INFO] OctagonAgentSolo. Step: 1340000. Time Elapsed: 2626.199 s. Mean Reward: 0.479. Std of Reward: 0.201. Training.
# [INFO] OctagonAgentSolo. Step: 1360000. Time Elapsed: 2664.818 s. Mean Reward: 0.489. Std of Reward: 0.177. Training.
# [INFO] OctagonAgentSolo. Step: 1380000. Time Elapsed: 2702.757 s. Mean Reward: 0.513. Std of Reward: 0.175. Training.
# [INFO] OctagonAgentSolo. Step: 1400000. Time Elapsed: 2740.764 s. Mean Reward: 0.463. Std of Reward: 0.227. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1399985.onnx
# [INFO] OctagonAgentSolo. Step: 1420000. Time Elapsed: 2779.466 s. Mean Reward: 0.487. Std of Reward: 0.200. Training.
# [INFO] OctagonAgentSolo. Step: 1440000. Time Elapsed: 2816.819 s. Mean Reward: 0.421. Std of Reward: 0.253. Training.
# [INFO] OctagonAgentSolo. Step: 1460000. Time Elapsed: 2855.454 s. Mean Reward: 0.478. Std of Reward: 0.215. Training.
# [INFO] OctagonAgentSolo. Step: 1480000. Time Elapsed: 2893.488 s. Mean Reward: 0.427. Std of Reward: 0.240. Training.
# [INFO] OctagonAgentSolo. Step: 1500000. Time Elapsed: 2932.574 s. Mean Reward: 0.434. Std of Reward: 0.239. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1499905.onnx
# [INFO] OctagonAgentSolo. Step: 1520000. Time Elapsed: 2971.137 s. Mean Reward: 0.341. Std of Reward: 0.300. Training.
# [INFO] OctagonAgentSolo. Step: 1540000. Time Elapsed: 3009.177 s. Mean Reward: 0.508. Std of Reward: 0.202. Training.
# [INFO] OctagonAgentSolo. Step: 1560000. Time Elapsed: 3048.169 s. Mean Reward: 0.420. Std of Reward: 0.253. Training.
# [INFO] OctagonAgentSolo. Step: 1580000. Time Elapsed: 3087.060 s. Mean Reward: 0.507. Std of Reward: 0.172. Training.
# [INFO] OctagonAgentSolo. Step: 1600000. Time Elapsed: 3124.617 s. Mean Reward: 0.486. Std of Reward: 0.187. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1599946.onnx
# [INFO] OctagonAgentSolo. Step: 1620000. Time Elapsed: 3163.354 s. Mean Reward: 0.448. Std of Reward: 0.230. Training.
# [INFO] OctagonAgentSolo. Step: 1640000. Time Elapsed: 3201.612 s. Mean Reward: 0.460. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 1660000. Time Elapsed: 3239.330 s. Mean Reward: 0.463. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 1680000. Time Elapsed: 3278.055 s. Mean Reward: 0.424. Std of Reward: 0.253. Training.
# [INFO] OctagonAgentSolo. Step: 1700000. Time Elapsed: 3315.883 s. Mean Reward: 0.361. Std of Reward: 0.282. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1699936.onnx
# [INFO] OctagonAgentSolo. Step: 1720000. Time Elapsed: 3354.284 s. Mean Reward: 0.443. Std of Reward: 0.238. Training.
# [INFO] OctagonAgentSolo. Step: 1740000. Time Elapsed: 3392.787 s. Mean Reward: 0.422. Std of Reward: 0.232. Training.
# [INFO] OctagonAgentSolo. Step: 1760000. Time Elapsed: 3431.304 s. Mean Reward: 0.447. Std of Reward: 0.233. Training.
# [INFO] OctagonAgentSolo. Step: 1780000. Time Elapsed: 3470.702 s. Mean Reward: 0.455. Std of Reward: 0.225. Training.
# [INFO] OctagonAgentSolo. Step: 1800000. Time Elapsed: 3508.899 s. Mean Reward: 0.450. Std of Reward: 0.224. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1799920.onnx
# [INFO] OctagonAgentSolo. Step: 1820000. Time Elapsed: 3547.890 s. Mean Reward: 0.495. Std of Reward: 0.193. Training.
# [INFO] OctagonAgentSolo. Step: 1840000. Time Elapsed: 3585.325 s. Mean Reward: 0.422. Std of Reward: 0.248. Training.
# [INFO] OctagonAgentSolo. Step: 1860000. Time Elapsed: 3623.590 s. Mean Reward: 0.409. Std of Reward: 0.247. Training.
# [INFO] OctagonAgentSolo. Step: 1880000. Time Elapsed: 3661.932 s. Mean Reward: 0.509. Std of Reward: 0.147. Training.
# [INFO] OctagonAgentSolo. Step: 1900000. Time Elapsed: 3701.058 s. Mean Reward: 0.469. Std of Reward: 0.203. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1899908.onnx
# [INFO] OctagonAgentSolo. Step: 1920000. Time Elapsed: 3739.479 s. Mean Reward: 0.452. Std of Reward: 0.226. Training.
# [INFO] OctagonAgentSolo. Step: 1940000. Time Elapsed: 3778.396 s. Mean Reward: 0.459. Std of Reward: 0.243. Training.
# [INFO] OctagonAgentSolo. Step: 1960000. Time Elapsed: 3815.985 s. Mean Reward: 0.450. Std of Reward: 0.235. Training.
# [INFO] OctagonAgentSolo. Step: 1980000. Time Elapsed: 3854.527 s. Mean Reward: 0.463. Std of Reward: 0.217. Training.
# [INFO] OctagonAgentSolo. Step: 2000000. Time Elapsed: 3893.126 s. Mean Reward: 0.409. Std of Reward: 0.264. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-1999990.onnx
# [INFO] OctagonAgentSolo. Step: 2020000. Time Elapsed: 3931.562 s. Mean Reward: 0.446. Std of Reward: 0.218. Training.
# [INFO] OctagonAgentSolo. Step: 2040000. Time Elapsed: 3971.082 s. Mean Reward: 0.372. Std of Reward: 0.280. Training.
# [INFO] OctagonAgentSolo. Step: 2060000. Time Elapsed: 4009.254 s. Mean Reward: 0.502. Std of Reward: 0.180. Training.
# [INFO] OctagonAgentSolo. Step: 2080000. Time Elapsed: 4047.646 s. Mean Reward: 0.403. Std of Reward: 0.319. Training.
# [INFO] OctagonAgentSolo. Step: 2100000. Time Elapsed: 4085.965 s. Mean Reward: 0.411. Std of Reward: 0.340. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2099898.onnx
# [INFO] OctagonAgentSolo. Step: 2120000. Time Elapsed: 4124.573 s. Mean Reward: 0.372. Std of Reward: 0.274. Training.
# [INFO] OctagonAgentSolo. Step: 2140000. Time Elapsed: 4162.481 s. Mean Reward: 0.510. Std of Reward: 0.175. Training.
# [INFO] OctagonAgentSolo. Step: 2160000. Time Elapsed: 4201.060 s. Mean Reward: 0.466. Std of Reward: 0.208. Training.
# [INFO] OctagonAgentSolo. Step: 2180000. Time Elapsed: 4238.921 s. Mean Reward: 0.475. Std of Reward: 0.226. Training.
# [INFO] OctagonAgentSolo. Step: 2200000. Time Elapsed: 4276.568 s. Mean Reward: 0.444. Std of Reward: 0.245. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2199907.onnx
# [INFO] OctagonAgentSolo. Step: 2220000. Time Elapsed: 4314.982 s. Mean Reward: 0.471. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 2240000. Time Elapsed: 4352.761 s. Mean Reward: 0.406. Std of Reward: 0.261. Training.
# [INFO] OctagonAgentSolo. Step: 2260000. Time Elapsed: 4390.051 s. Mean Reward: 0.460. Std of Reward: 0.212. Training.
# [INFO] OctagonAgentSolo. Step: 2280000. Time Elapsed: 4428.164 s. Mean Reward: 0.396. Std of Reward: 0.271. Training.
# [INFO] OctagonAgentSolo. Step: 2300000. Time Elapsed: 4465.792 s. Mean Reward: 0.472. Std of Reward: 0.217. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2299909.onnx
# [INFO] OctagonAgentSolo. Step: 2320000. Time Elapsed: 4504.573 s. Mean Reward: 0.350. Std of Reward: 0.300. Training.
# [INFO] OctagonAgentSolo. Step: 2340000. Time Elapsed: 4542.840 s. Mean Reward: 0.414. Std of Reward: 0.255. Training.
# [INFO] OctagonAgentSolo. Step: 2360000. Time Elapsed: 4580.093 s. Mean Reward: 0.366. Std of Reward: 0.272. Training.
# [INFO] OctagonAgentSolo. Step: 2380000. Time Elapsed: 4618.663 s. Mean Reward: 0.406. Std of Reward: 0.255. Training.
# [INFO] OctagonAgentSolo. Step: 2400000. Time Elapsed: 4655.926 s. Mean Reward: 0.490. Std of Reward: 0.204. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2399907.onnx
# [INFO] OctagonAgentSolo. Step: 2420000. Time Elapsed: 4694.441 s. Mean Reward: 0.450. Std of Reward: 0.232. Training.
# [INFO] OctagonAgentSolo. Step: 2440000. Time Elapsed: 4732.024 s. Mean Reward: 0.458. Std of Reward: 0.223. Training.
# [INFO] OctagonAgentSolo. Step: 2460000. Time Elapsed: 4769.949 s. Mean Reward: 0.405. Std of Reward: 0.265. Training.
# [INFO] OctagonAgentSolo. Step: 2480000. Time Elapsed: 4808.414 s. Mean Reward: 0.460. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 2500000. Time Elapsed: 4846.279 s. Mean Reward: 0.454. Std of Reward: 0.225. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2499969.onnx
# [INFO] OctagonAgentSolo. Step: 2520000. Time Elapsed: 4883.676 s. Mean Reward: 0.492. Std of Reward: 0.197. Training.
# [INFO] OctagonAgentSolo. Step: 2540000. Time Elapsed: 4921.645 s. Mean Reward: 0.394. Std of Reward: 0.269. Training.
# [INFO] OctagonAgentSolo. Step: 2560000. Time Elapsed: 4958.926 s. Mean Reward: 0.399. Std of Reward: 0.276. Training.
# [INFO] OctagonAgentSolo. Step: 2580000. Time Elapsed: 4996.570 s. Mean Reward: 0.410. Std of Reward: 0.256. Training.
# [INFO] OctagonAgentSolo. Step: 2600000. Time Elapsed: 5035.320 s. Mean Reward: 0.452. Std of Reward: 0.224. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2599899.onnx
# [INFO] OctagonAgentSolo. Step: 2620000. Time Elapsed: 5073.512 s. Mean Reward: 0.437. Std of Reward: 0.233. Training.
# [INFO] OctagonAgentSolo. Step: 2640000. Time Elapsed: 5111.740 s. Mean Reward: 0.493. Std of Reward: 0.195. Training.
# [INFO] OctagonAgentSolo. Step: 2660000. Time Elapsed: 5149.456 s. Mean Reward: 0.441. Std of Reward: 0.231. Training.
# [INFO] OctagonAgentSolo. Step: 2680000. Time Elapsed: 5187.865 s. Mean Reward: 0.386. Std of Reward: 0.271. Training.
# [INFO] OctagonAgentSolo. Step: 2700000. Time Elapsed: 5225.589 s. Mean Reward: 0.436. Std of Reward: 0.228. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2699949.onnx
# [INFO] OctagonAgentSolo. Step: 2720000. Time Elapsed: 5263.253 s. Mean Reward: 0.413. Std of Reward: 0.255. Training.
# [INFO] OctagonAgentSolo. Step: 2740000. Time Elapsed: 5301.381 s. Mean Reward: 0.440. Std of Reward: 0.249. Training.
# [INFO] OctagonAgentSolo. Step: 2760000. Time Elapsed: 5338.441 s. Mean Reward: 0.339. Std of Reward: 0.283. Training.
# [INFO] OctagonAgentSolo. Step: 2780000. Time Elapsed: 5375.805 s. Mean Reward: 0.495. Std of Reward: 0.191. Training.
# [INFO] OctagonAgentSolo. Step: 2800000. Time Elapsed: 5413.909 s. Mean Reward: 0.510. Std of Reward: 0.183. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2799893.onnx
# [INFO] OctagonAgentSolo. Step: 2820000. Time Elapsed: 5452.322 s. Mean Reward: 0.422. Std of Reward: 0.247. Training.
# [INFO] OctagonAgentSolo. Step: 2840000. Time Elapsed: 5489.965 s. Mean Reward: 0.419. Std of Reward: 0.247. Training.
# [INFO] OctagonAgentSolo. Step: 2860000. Time Elapsed: 5528.782 s. Mean Reward: 0.444. Std of Reward: 0.236. Training.
# [INFO] OctagonAgentSolo. Step: 2880000. Time Elapsed: 5566.884 s. Mean Reward: 0.400. Std of Reward: 0.263. Training.
# [INFO] OctagonAgentSolo. Step: 2900000. Time Elapsed: 5604.542 s. Mean Reward: 0.412. Std of Reward: 0.241. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2899872.onnx
# [INFO] OctagonAgentSolo. Step: 2920000. Time Elapsed: 5642.670 s. Mean Reward: 0.374. Std of Reward: 0.278. Training.
# [INFO] OctagonAgentSolo. Step: 2940000. Time Elapsed: 5679.972 s. Mean Reward: 0.416. Std of Reward: 0.251. Training.
# [INFO] OctagonAgentSolo. Step: 2960000. Time Elapsed: 5718.192 s. Mean Reward: 0.458. Std of Reward: 0.220. Training.
# [INFO] OctagonAgentSolo. Step: 2980000. Time Elapsed: 5755.735 s. Mean Reward: 0.417. Std of Reward: 0.248. Training.
# [INFO] OctagonAgentSolo. Step: 3000000. Time Elapsed: 5793.270 s. Mean Reward: 0.365. Std of Reward: 0.282. Training.
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-2999896.onnx
# [INFO] Exported results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-3000024.onnx
# [INFO] Copied results/260518_0007/OctagonAgentSolo/OctagonAgentSolo-3000024.onnx to results/260518_0007/OctagonAgentSolo.onnx.
# patched yaml for run 260518_0008 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumAndHigherRndSoloConfig.yaml
# launching training for run 260518_0008 with config /home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/WallSepCurriculumAndHigherRndSoloConfig.yaml
# Using seed: 17 for training run 260518_0008
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0,
#   ml-agents-envs: 1.1.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Hyperparameters for behavior name OctagonAgentSolo:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	10240
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	100000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.02
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	30
# 	even_checkpoints:	False
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Parameter 'step_penalty' is in lesson 'step_penalty' and has value 'Float: value=0.001'.
# [INFO] Parameter 'sep_weight_1' is in lesson 'bias_180' and has value 'Float: value=0.2'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'bias_180' and has value 'Float: value=0.2'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'bias_180' and has value 'Float: value=0.6'.
# [INFO] OctagonAgentSolo. Step: 20000. Time Elapsed: 38.659 s. Mean Reward: -0.963. Std of Reward: 0.007. Training.
# [INFO] OctagonAgentSolo. Step: 40000. Time Elapsed: 75.711 s. Mean Reward: -0.958. Std of Reward: 0.006. Training.
# [INFO] OctagonAgentSolo. Step: 60000. Time Elapsed: 112.774 s. Mean Reward: -0.753. Std of Reward: 0.498. Training.
# [INFO] OctagonAgentSolo. Step: 80000. Time Elapsed: 150.089 s. Mean Reward: -0.207. Std of Reward: 0.744. Training.
# [INFO] OctagonAgentSolo. Step: 100000. Time Elapsed: 187.070 s. Mean Reward: 0.008. Std of Reward: 0.560. Training.
# /home/tom/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-99940.onnx
# [INFO] OctagonAgentSolo. Step: 120000. Time Elapsed: 224.896 s. Mean Reward: -0.444. Std of Reward: 0.529. Training.
# [INFO] OctagonAgentSolo. Step: 140000. Time Elapsed: 261.892 s. Mean Reward: -0.428. Std of Reward: 0.537. Training.
# [INFO] OctagonAgentSolo. Step: 160000. Time Elapsed: 299.429 s. Mean Reward: -0.084. Std of Reward: 0.543. Training.
# [INFO] OctagonAgentSolo. Step: 180000. Time Elapsed: 337.598 s. Mean Reward: -0.080. Std of Reward: 0.513. Training.
# [INFO] OctagonAgentSolo. Step: 200000. Time Elapsed: 375.124 s. Mean Reward: 0.100. Std of Reward: 0.331. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-199950.onnx
# [INFO] OctagonAgentSolo. Step: 220000. Time Elapsed: 413.064 s. Mean Reward: 0.071. Std of Reward: 0.426. Training.
# [INFO] OctagonAgentSolo. Step: 240000. Time Elapsed: 450.511 s. Mean Reward: -0.028. Std of Reward: 0.505. Training.
# [INFO] OctagonAgentSolo. Step: 260000. Time Elapsed: 488.548 s. Mean Reward: 0.004. Std of Reward: 0.501. Training.
# [INFO] OctagonAgentSolo. Step: 280000. Time Elapsed: 526.312 s. Mean Reward: 0.171. Std of Reward: 0.404. Training.
# [INFO] OctagonAgentSolo. Step: 300000. Time Elapsed: 564.308 s. Mean Reward: 0.173. Std of Reward: 0.364. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-299933.onnx
# [INFO] OctagonAgentSolo. Step: 320000. Time Elapsed: 601.961 s. Mean Reward: 0.100. Std of Reward: 0.369. Training.
# [INFO] OctagonAgentSolo. Step: 340000. Time Elapsed: 639.759 s. Mean Reward: 0.140. Std of Reward: 0.471. Training.
# [INFO] OctagonAgentSolo. Step: 360000. Time Elapsed: 677.079 s. Mean Reward: 0.166. Std of Reward: 0.349. Training.
# [INFO] OctagonAgentSolo. Step: 380000. Time Elapsed: 714.903 s. Mean Reward: 0.328. Std of Reward: 0.443. Training.
# [INFO] OctagonAgentSolo. Step: 400000. Time Elapsed: 752.365 s. Mean Reward: 0.034. Std of Reward: 0.510. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-399977.onnx
# [INFO] OctagonAgentSolo. Step: 420000. Time Elapsed: 790.038 s. Mean Reward: 0.015. Std of Reward: 0.497. Training.
# [INFO] OctagonAgentSolo. Step: 440000. Time Elapsed: 827.397 s. Mean Reward: 0.203. Std of Reward: 0.505. Training.
# [INFO] OctagonAgentSolo. Step: 460000. Time Elapsed: 865.394 s. Mean Reward: 0.170. Std of Reward: 0.385. Training.
# [INFO] OctagonAgentSolo. Step: 480000. Time Elapsed: 903.344 s. Mean Reward: 0.187. Std of Reward: 0.398. Training.
# [INFO] OctagonAgentSolo. Step: 500000. Time Elapsed: 941.393 s. Mean Reward: 0.193. Std of Reward: 0.380. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-499874.onnx
# [INFO] OctagonAgentSolo. Step: 520000. Time Elapsed: 978.730 s. Mean Reward: 0.160. Std of Reward: 0.301. Training.
# [INFO] OctagonAgentSolo. Step: 540000. Time Elapsed: 1016.567 s. Mean Reward: 0.150. Std of Reward: 0.364. Training.
# [INFO] OctagonAgentSolo. Step: 560000. Time Elapsed: 1054.473 s. Mean Reward: 0.262. Std of Reward: 0.295. Training.
# [INFO] OctagonAgentSolo. Step: 580000. Time Elapsed: 1091.647 s. Mean Reward: 0.250. Std of Reward: 0.319. Training.
# [INFO] OctagonAgentSolo. Step: 600000. Time Elapsed: 1129.175 s. Mean Reward: 0.231. Std of Reward: 0.369. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-599940.onnx
# [INFO] Parameter 'sep_weight_1' is in lesson 'transition' and has value 'Float: value=0.35'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'transition' and has value 'Float: value=0.25'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'transition' and has value 'Float: value=0.4'.
# [INFO] OctagonAgentSolo. Step: 620000. Time Elapsed: 1167.011 s. Mean Reward: 0.290. Std of Reward: 0.307. Training.
# [INFO] OctagonAgentSolo. Step: 640000. Time Elapsed: 1205.011 s. Mean Reward: 0.320. Std of Reward: 0.301. Training.
# [INFO] OctagonAgentSolo. Step: 660000. Time Elapsed: 1243.007 s. Mean Reward: 0.273. Std of Reward: 0.283. Training.
# [INFO] OctagonAgentSolo. Step: 680000. Time Elapsed: 1280.926 s. Mean Reward: 0.206. Std of Reward: 0.362. Training.
# [INFO] OctagonAgentSolo. Step: 700000. Time Elapsed: 1318.418 s. Mean Reward: 0.228. Std of Reward: 0.298. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-699877.onnx
# [INFO] OctagonAgentSolo. Step: 720000. Time Elapsed: 1355.926 s. Mean Reward: 0.339. Std of Reward: 0.296. Training.
# [INFO] OctagonAgentSolo. Step: 740000. Time Elapsed: 1394.201 s. Mean Reward: 0.338. Std of Reward: 0.277. Training.
# [INFO] OctagonAgentSolo. Step: 760000. Time Elapsed: 1431.201 s. Mean Reward: 0.323. Std of Reward: 0.314. Training.
# [INFO] OctagonAgentSolo. Step: 780000. Time Elapsed: 1469.516 s. Mean Reward: 0.274. Std of Reward: 0.312. Training.
# [INFO] OctagonAgentSolo. Step: 800000. Time Elapsed: 1506.964 s. Mean Reward: 0.316. Std of Reward: 0.286. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-799891.onnx
# [INFO] OctagonAgentSolo. Step: 820000. Time Elapsed: 1544.998 s. Mean Reward: 0.250. Std of Reward: 0.308. Training.
# [INFO] OctagonAgentSolo. Step: 840000. Time Elapsed: 1583.224 s. Mean Reward: 0.275. Std of Reward: 0.366. Training.
# [INFO] OctagonAgentSolo. Step: 860000. Time Elapsed: 1623.448 s. Mean Reward: 0.247. Std of Reward: 0.317. Training.
# [INFO] OctagonAgentSolo. Step: 880000. Time Elapsed: 1665.123 s. Mean Reward: 0.276. Std of Reward: 0.305. Training.
# [INFO] OctagonAgentSolo. Step: 900000. Time Elapsed: 1705.982 s. Mean Reward: 0.354. Std of Reward: 0.283. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-899875.onnx
# [INFO] OctagonAgentSolo. Step: 920000. Time Elapsed: 1747.717 s. Mean Reward: 0.381. Std of Reward: 0.282. Training.
# [INFO] OctagonAgentSolo. Step: 940000. Time Elapsed: 1789.048 s. Mean Reward: 0.343. Std of Reward: 0.296. Training.
# [INFO] OctagonAgentSolo. Step: 960000. Time Elapsed: 1830.122 s. Mean Reward: 0.231. Std of Reward: 0.308. Training.
# [INFO] OctagonAgentSolo. Step: 980000. Time Elapsed: 1871.506 s. Mean Reward: 0.304. Std of Reward: 0.315. Training.
# [INFO] OctagonAgentSolo. Step: 1000000. Time Elapsed: 1912.087 s. Mean Reward: 0.243. Std of Reward: 0.304. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-999934.onnx
# [INFO] OctagonAgentSolo. Step: 1020000. Time Elapsed: 1952.418 s. Mean Reward: 0.361. Std of Reward: 0.284. Training.
# [INFO] OctagonAgentSolo. Step: 1040000. Time Elapsed: 1992.915 s. Mean Reward: 0.263. Std of Reward: 0.363. Training.
# [INFO] OctagonAgentSolo. Step: 1060000. Time Elapsed: 2033.667 s. Mean Reward: 0.337. Std of Reward: 0.287. Training.
# [INFO] OctagonAgentSolo. Step: 1080000. Time Elapsed: 2075.093 s. Mean Reward: 0.305. Std of Reward: 0.323. Training.
# [INFO] OctagonAgentSolo. Step: 1100000. Time Elapsed: 2116.078 s. Mean Reward: 0.342. Std of Reward: 0.302. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1099968.onnx
# [INFO] OctagonAgentSolo. Step: 1120000. Time Elapsed: 2157.312 s. Mean Reward: 0.366. Std of Reward: 0.287. Training.
# [INFO] OctagonAgentSolo. Step: 1140000. Time Elapsed: 2198.560 s. Mean Reward: 0.287. Std of Reward: 0.307. Training.
# [INFO] OctagonAgentSolo. Step: 1160000. Time Elapsed: 2239.822 s. Mean Reward: 0.313. Std of Reward: 0.310. Training.
# [INFO] OctagonAgentSolo. Step: 1180000. Time Elapsed: 2280.916 s. Mean Reward: 0.329. Std of Reward: 0.308. Training.
# [INFO] OctagonAgentSolo. Step: 1200000. Time Elapsed: 2322.304 s. Mean Reward: 0.232. Std of Reward: 0.305. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1199937.onnx
# [INFO] Parameter 'sep_weight_1' is in lesson 'target_distribution' and has value 'Float: value=0.5'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] OctagonAgentSolo. Step: 1220000. Time Elapsed: 2363.579 s. Mean Reward: 0.308. Std of Reward: 0.303. Training.
# [INFO] OctagonAgentSolo. Step: 1240000. Time Elapsed: 2404.186 s. Mean Reward: 0.361. Std of Reward: 0.299. Training.
# [INFO] OctagonAgentSolo. Step: 1260000. Time Elapsed: 2444.695 s. Mean Reward: 0.325. Std of Reward: 0.302. Training.
# [INFO] OctagonAgentSolo. Step: 1280000. Time Elapsed: 2485.436 s. Mean Reward: 0.357. Std of Reward: 0.279. Training.
# [INFO] OctagonAgentSolo. Step: 1300000. Time Elapsed: 2526.587 s. Mean Reward: 0.445. Std of Reward: 0.244. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1299921.onnx
# [INFO] OctagonAgentSolo. Step: 1320000. Time Elapsed: 2567.653 s. Mean Reward: 0.408. Std of Reward: 0.264. Training.
# [INFO] OctagonAgentSolo. Step: 1340000. Time Elapsed: 2607.544 s. Mean Reward: 0.367. Std of Reward: 0.291. Training.
# [INFO] OctagonAgentSolo. Step: 1360000. Time Elapsed: 2646.647 s. Mean Reward: 0.468. Std of Reward: 0.208. Training.
# [INFO] OctagonAgentSolo. Step: 1380000. Time Elapsed: 2686.775 s. Mean Reward: 0.387. Std of Reward: 0.272. Training.
# [INFO] OctagonAgentSolo. Step: 1400000. Time Elapsed: 2727.032 s. Mean Reward: 0.475. Std of Reward: 0.220. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1399905.onnx
# [INFO] OctagonAgentSolo. Step: 1420000. Time Elapsed: 2765.528 s. Mean Reward: 0.417. Std of Reward: 0.257. Training.
# [INFO] OctagonAgentSolo. Step: 1440000. Time Elapsed: 2804.146 s. Mean Reward: 0.488. Std of Reward: 0.176. Training.
# [INFO] OctagonAgentSolo. Step: 1460000. Time Elapsed: 2843.661 s. Mean Reward: 0.368. Std of Reward: 0.282. Training.
# [INFO] OctagonAgentSolo. Step: 1480000. Time Elapsed: 2882.454 s. Mean Reward: 0.438. Std of Reward: 0.223. Training.
# [INFO] OctagonAgentSolo. Step: 1500000. Time Elapsed: 2919.957 s. Mean Reward: 0.434. Std of Reward: 0.229. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1499936.onnx
# [INFO] OctagonAgentSolo. Step: 1520000. Time Elapsed: 2959.916 s. Mean Reward: 0.454. Std of Reward: 0.220. Training.
# [INFO] OctagonAgentSolo. Step: 1540000. Time Elapsed: 2997.320 s. Mean Reward: 0.457. Std of Reward: 0.221. Training.
# [INFO] OctagonAgentSolo. Step: 1560000. Time Elapsed: 3036.204 s. Mean Reward: 0.464. Std of Reward: 0.210. Training.
# [INFO] OctagonAgentSolo. Step: 1580000. Time Elapsed: 3074.937 s. Mean Reward: 0.479. Std of Reward: 0.193. Training.
# [INFO] OctagonAgentSolo. Step: 1600000. Time Elapsed: 3113.698 s. Mean Reward: 0.463. Std of Reward: 0.228. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1599960.onnx
# [INFO] OctagonAgentSolo. Step: 1620000. Time Elapsed: 3153.266 s. Mean Reward: 0.473. Std of Reward: 0.214. Training.
# [INFO] OctagonAgentSolo. Step: 1640000. Time Elapsed: 3191.435 s. Mean Reward: 0.465. Std of Reward: 0.215. Training.
# [INFO] OctagonAgentSolo. Step: 1660000. Time Elapsed: 3232.266 s. Mean Reward: 0.434. Std of Reward: 0.227. Training.
# [INFO] OctagonAgentSolo. Step: 1680000. Time Elapsed: 3271.982 s. Mean Reward: 0.453. Std of Reward: 0.231. Training.
# [INFO] OctagonAgentSolo. Step: 1700000. Time Elapsed: 3312.670 s. Mean Reward: 0.456. Std of Reward: 0.219. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1699883.onnx
# [INFO] OctagonAgentSolo. Step: 1720000. Time Elapsed: 3352.758 s. Mean Reward: 0.443. Std of Reward: 0.235. Training.
# [INFO] OctagonAgentSolo. Step: 1740000. Time Elapsed: 3393.171 s. Mean Reward: 0.416. Std of Reward: 0.242. Training.
# [INFO] OctagonAgentSolo. Step: 1760000. Time Elapsed: 3433.716 s. Mean Reward: 0.437. Std of Reward: 0.209. Training.
# [INFO] OctagonAgentSolo. Step: 1780000. Time Elapsed: 3473.030 s. Mean Reward: 0.450. Std of Reward: 0.225. Training.
# [INFO] OctagonAgentSolo. Step: 1800000. Time Elapsed: 3512.472 s. Mean Reward: 0.403. Std of Reward: 0.250. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1799928.onnx
# [INFO] OctagonAgentSolo. Step: 1820000. Time Elapsed: 3552.660 s. Mean Reward: 0.477. Std of Reward: 0.191. Training.
# [INFO] OctagonAgentSolo. Step: 1840000. Time Elapsed: 3591.231 s. Mean Reward: 0.502. Std of Reward: 0.177. Training.
# [INFO] OctagonAgentSolo. Step: 1860000. Time Elapsed: 3629.596 s. Mean Reward: 0.448. Std of Reward: 0.225. Training.
# [INFO] OctagonAgentSolo. Step: 1880000. Time Elapsed: 3668.250 s. Mean Reward: 0.468. Std of Reward: 0.203. Training.
# [INFO] OctagonAgentSolo. Step: 1900000. Time Elapsed: 3707.577 s. Mean Reward: 0.470. Std of Reward: 0.217. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1899950.onnx
# [INFO] OctagonAgentSolo. Step: 1920000. Time Elapsed: 3746.668 s. Mean Reward: 0.393. Std of Reward: 0.266. Training.
# [INFO] OctagonAgentSolo. Step: 1940000. Time Elapsed: 3785.426 s. Mean Reward: 0.478. Std of Reward: 0.199. Training.
# [INFO] OctagonAgentSolo. Step: 1960000. Time Elapsed: 3824.936 s. Mean Reward: 0.451. Std of Reward: 0.245. Training.
# [INFO] OctagonAgentSolo. Step: 1980000. Time Elapsed: 3863.414 s. Mean Reward: 0.425. Std of Reward: 0.237. Training.
# [INFO] OctagonAgentSolo. Step: 2000000. Time Elapsed: 3903.241 s. Mean Reward: 0.422. Std of Reward: 0.250. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-1999913.onnx
# [INFO] OctagonAgentSolo. Step: 2020000. Time Elapsed: 3942.440 s. Mean Reward: 0.466. Std of Reward: 0.229. Training.
# [INFO] OctagonAgentSolo. Step: 2040000. Time Elapsed: 3982.508 s. Mean Reward: 0.463. Std of Reward: 0.223. Training.
# [INFO] OctagonAgentSolo. Step: 2060000. Time Elapsed: 4022.100 s. Mean Reward: 0.428. Std of Reward: 0.226. Training.
# [INFO] OctagonAgentSolo. Step: 2080000. Time Elapsed: 4061.028 s. Mean Reward: 0.458. Std of Reward: 0.213. Training.
# [INFO] OctagonAgentSolo. Step: 2100000. Time Elapsed: 4099.917 s. Mean Reward: 0.482. Std of Reward: 0.200. Training.
# [INFO] Exported results/260518_0008/OctagonAgentSolo/OctagonAgentSolo-2099942.onnx
# ...
# [INFO] OctagonAgentSolo. Step: 720000. Time Elapsed: 1394.308 s. Mean Reward: 0.430. Std of Reward: 0.237. Training.
# [INFO] OctagonAgentSolo. Step: 740000. Time Elapsed: 1433.073 s. Mean Reward: 0.413. Std of Reward: 0.261. Training.
# [INFO] OctagonAgentSolo. Step: 760000. Time Elapsed: 1471.661 s. Mean Reward: 0.389. Std of Reward: 0.277. Training.
# [INFO] OctagonAgentSolo. Step: 780000. Time Elapsed: 1510.484 s. Mean Reward: 0.423. Std of Reward: 0.269. Training.
# [INFO] OctagonAgentSolo. Step: 800000. Time Elapsed: 1548.759 s. Mean Reward: 0.328. Std of Reward: 0.292. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-799937.onnx
# [INFO] OctagonAgentSolo. Step: 820000. Time Elapsed: 1588.473 s. Mean Reward: 0.411. Std of Reward: 0.256. Training.
# [INFO] OctagonAgentSolo. Step: 840000. Time Elapsed: 1627.196 s. Mean Reward: 0.387. Std of Reward: 0.270. Training.
# [INFO] OctagonAgentSolo. Step: 860000. Time Elapsed: 1666.162 s. Mean Reward: 0.360. Std of Reward: 0.270. Training.
# [INFO] OctagonAgentSolo. Step: 880000. Time Elapsed: 1705.876 s. Mean Reward: 0.479. Std of Reward: 0.193. Training.
# [INFO] OctagonAgentSolo. Step: 900000. Time Elapsed: 1744.800 s. Mean Reward: 0.403. Std of Reward: 0.252. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-899972.onnx
# [INFO] OctagonAgentSolo. Step: 920000. Time Elapsed: 1783.819 s. Mean Reward: 0.441. Std of Reward: 0.225. Training.
# [INFO] OctagonAgentSolo. Step: 940000. Time Elapsed: 1822.511 s. Mean Reward: 0.469. Std of Reward: 0.195. Training.
# [INFO] OctagonAgentSolo. Step: 960000. Time Elapsed: 1861.479 s. Mean Reward: 0.432. Std of Reward: 0.254. Training.
# [INFO] OctagonAgentSolo. Step: 980000. Time Elapsed: 1899.105 s. Mean Reward: 0.382. Std of Reward: 0.278. Training.
# [INFO] OctagonAgentSolo. Step: 1000000. Time Elapsed: 1937.908 s. Mean Reward: 0.455. Std of Reward: 0.204. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-999934.onnx
# [INFO] OctagonAgentSolo. Step: 1020000. Time Elapsed: 1976.074 s. Mean Reward: 0.444. Std of Reward: 0.240. Training.
# [INFO] OctagonAgentSolo. Step: 1040000. Time Elapsed: 2014.185 s. Mean Reward: 0.387. Std of Reward: 0.280. Training.
# [INFO] OctagonAgentSolo. Step: 1060000. Time Elapsed: 2053.061 s. Mean Reward: 0.375. Std of Reward: 0.285. Training.
# [INFO] OctagonAgentSolo. Step: 1080000. Time Elapsed: 2092.351 s. Mean Reward: 0.414. Std of Reward: 0.249. Training.
# [INFO] OctagonAgentSolo. Step: 1100000. Time Elapsed: 2131.734 s. Mean Reward: 0.488. Std of Reward: 0.199. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1099882.onnx
# [INFO] OctagonAgentSolo. Step: 1120000. Time Elapsed: 2171.222 s. Mean Reward: 0.338. Std of Reward: 0.288. Training.
# [INFO] OctagonAgentSolo. Step: 1140000. Time Elapsed: 2210.075 s. Mean Reward: 0.435. Std of Reward: 0.260. Training.
# [INFO] OctagonAgentSolo. Step: 1160000. Time Elapsed: 2249.258 s. Mean Reward: 0.383. Std of Reward: 0.290. Training.
# [INFO] OctagonAgentSolo. Step: 1180000. Time Elapsed: 2286.952 s. Mean Reward: 0.371. Std of Reward: 0.290. Training.
# [INFO] OctagonAgentSolo. Step: 1200000. Time Elapsed: 2325.220 s. Mean Reward: 0.426. Std of Reward: 0.251. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1199895.onnx
# [INFO] Parameter 'sep_weight_1' is in lesson 'target_distribution' and has value 'Float: value=0.5'.
# [INFO] Parameter 'sep_weight_2' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] Parameter 'sep_weight_4' is in lesson 'target_distribution' and has value 'Float: value=0.25'.
# [INFO] OctagonAgentSolo. Step: 1220000. Time Elapsed: 2363.966 s. Mean Reward: 0.398. Std of Reward: 0.317. Training.
# [INFO] OctagonAgentSolo. Step: 1240000. Time Elapsed: 2403.109 s. Mean Reward: 0.485. Std of Reward: 0.207. Training.
# [INFO] OctagonAgentSolo. Step: 1260000. Time Elapsed: 2442.302 s. Mean Reward: 0.447. Std of Reward: 0.238. Training.
# [INFO] OctagonAgentSolo. Step: 1280000. Time Elapsed: 2481.319 s. Mean Reward: 0.442. Std of Reward: 0.222. Training.
# [INFO] OctagonAgentSolo. Step: 1300000. Time Elapsed: 2521.058 s. Mean Reward: 0.457. Std of Reward: 0.222. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1299936.onnx
# [INFO] OctagonAgentSolo. Step: 1320000. Time Elapsed: 2559.285 s. Mean Reward: 0.510. Std of Reward: 0.162. Training.
# [INFO] OctagonAgentSolo. Step: 1340000. Time Elapsed: 2598.120 s. Mean Reward: 0.441. Std of Reward: 0.232. Training.
# [INFO] OctagonAgentSolo. Step: 1360000. Time Elapsed: 2636.480 s. Mean Reward: 0.482. Std of Reward: 0.200. Training.
# [INFO] OctagonAgentSolo. Step: 1380000. Time Elapsed: 2675.241 s. Mean Reward: 0.438. Std of Reward: 0.238. Training.
# [INFO] OctagonAgentSolo. Step: 1400000. Time Elapsed: 2712.993 s. Mean Reward: 0.486. Std of Reward: 0.208. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1399882.onnx
# [INFO] OctagonAgentSolo. Step: 1420000. Time Elapsed: 2751.832 s. Mean Reward: 0.498. Std of Reward: 0.170. Training.
# [INFO] OctagonAgentSolo. Step: 1440000. Time Elapsed: 2790.683 s. Mean Reward: 0.474. Std of Reward: 0.213. Training.
# [INFO] OctagonAgentSolo. Step: 1460000. Time Elapsed: 2829.103 s. Mean Reward: 0.541. Std of Reward: 0.102. Training.
# [INFO] OctagonAgentSolo. Step: 1480000. Time Elapsed: 2868.006 s. Mean Reward: 0.492. Std of Reward: 0.191. Training.
# [INFO] OctagonAgentSolo. Step: 1500000. Time Elapsed: 2907.488 s. Mean Reward: 0.477. Std of Reward: 0.194. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1499993.onnx
# [INFO] OctagonAgentSolo. Step: 1520000. Time Elapsed: 2946.722 s. Mean Reward: 0.444. Std of Reward: 0.237. Training.
# [INFO] OctagonAgentSolo. Step: 1540000. Time Elapsed: 2986.362 s. Mean Reward: 0.524. Std of Reward: 0.150. Training.
# [INFO] OctagonAgentSolo. Step: 1560000. Time Elapsed: 3025.826 s. Mean Reward: 0.466. Std of Reward: 0.195. Training.
# [INFO] OctagonAgentSolo. Step: 1580000. Time Elapsed: 3064.400 s. Mean Reward: 0.531. Std of Reward: 0.141. Training.
# [INFO] OctagonAgentSolo. Step: 1600000. Time Elapsed: 3102.669 s. Mean Reward: 0.524. Std of Reward: 0.136. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1599981.onnx
# [INFO] OctagonAgentSolo. Step: 1620000. Time Elapsed: 3141.462 s. Mean Reward: 0.524. Std of Reward: 0.112. Training.
# [INFO] OctagonAgentSolo. Step: 1640000. Time Elapsed: 3180.188 s. Mean Reward: 0.530. Std of Reward: 0.109. Training.
# [INFO] OctagonAgentSolo. Step: 1660000. Time Elapsed: 3219.385 s. Mean Reward: 0.545. Std of Reward: 0.056. Training.
# [INFO] OctagonAgentSolo. Step: 1680000. Time Elapsed: 3258.667 s. Mean Reward: 0.521. Std of Reward: 0.146. Training.
# [INFO] OctagonAgentSolo. Step: 1700000. Time Elapsed: 3297.838 s. Mean Reward: 0.517. Std of Reward: 0.124. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1699925.onnx
# [INFO] OctagonAgentSolo. Step: 1720000. Time Elapsed: 3336.809 s. Mean Reward: 0.514. Std of Reward: 0.147. Training.
# [INFO] OctagonAgentSolo. Step: 1740000. Time Elapsed: 3375.997 s. Mean Reward: 0.488. Std of Reward: 0.199. Training.
# [INFO] OctagonAgentSolo. Step: 1760000. Time Elapsed: 3413.855 s. Mean Reward: 0.518. Std of Reward: 0.142. Training.
# [INFO] OctagonAgentSolo. Step: 1780000. Time Elapsed: 3452.482 s. Mean Reward: 0.501. Std of Reward: 0.168. Training.
# [INFO] OctagonAgentSolo. Step: 1800000. Time Elapsed: 3491.307 s. Mean Reward: 0.525. Std of Reward: 0.108. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1799875.onnx
# [INFO] OctagonAgentSolo. Step: 1820000. Time Elapsed: 3529.735 s. Mean Reward: 0.535. Std of Reward: 0.044. Training.
# [INFO] OctagonAgentSolo. Step: 1840000. Time Elapsed: 3568.383 s. Mean Reward: 0.537. Std of Reward: 0.065. Training.
# [INFO] OctagonAgentSolo. Step: 1860000. Time Elapsed: 3606.859 s. Mean Reward: 0.541. Std of Reward: 0.046. Training.
# [INFO] OctagonAgentSolo. Step: 1880000. Time Elapsed: 3645.462 s. Mean Reward: 0.538. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 1900000. Time Elapsed: 3683.756 s. Mean Reward: 0.538. Std of Reward: 0.053. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1899964.onnx
# [INFO] OctagonAgentSolo. Step: 1920000. Time Elapsed: 3722.999 s. Mean Reward: 0.529. Std of Reward: 0.045. Training.
# [INFO] OctagonAgentSolo. Step: 1940000. Time Elapsed: 3761.859 s. Mean Reward: 0.542. Std of Reward: 0.044. Training.
# [INFO] OctagonAgentSolo. Step: 1960000. Time Elapsed: 3801.570 s. Mean Reward: 0.534. Std of Reward: 0.042. Training.
# [INFO] OctagonAgentSolo. Step: 1980000. Time Elapsed: 3840.911 s. Mean Reward: 0.553. Std of Reward: 0.049. Training.
# [INFO] OctagonAgentSolo. Step: 2000000. Time Elapsed: 3879.450 s. Mean Reward: 0.548. Std of Reward: 0.049. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-1999913.onnx
# [INFO] OctagonAgentSolo. Step: 2020000. Time Elapsed: 3918.562 s. Mean Reward: 0.553. Std of Reward: 0.045. Training.
# [INFO] OctagonAgentSolo. Step: 2040000. Time Elapsed: 3957.007 s. Mean Reward: 0.537. Std of Reward: 0.042. Training.
# [INFO] OctagonAgentSolo. Step: 2060000. Time Elapsed: 3995.316 s. Mean Reward: 0.550. Std of Reward: 0.043. Training.
# [INFO] OctagonAgentSolo. Step: 2080000. Time Elapsed: 4034.354 s. Mean Reward: 0.539. Std of Reward: 0.054. Training.
# [INFO] OctagonAgentSolo. Step: 2100000. Time Elapsed: 4073.637 s. Mean Reward: 0.546. Std of Reward: 0.044. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2099919.onnx
# [INFO] OctagonAgentSolo. Step: 2120000. Time Elapsed: 4112.819 s. Mean Reward: 0.539. Std of Reward: 0.039. Training.
# [INFO] OctagonAgentSolo. Step: 2140000. Time Elapsed: 4152.651 s. Mean Reward: 0.545. Std of Reward: 0.051. Training.
# [INFO] OctagonAgentSolo. Step: 2160000. Time Elapsed: 4192.046 s. Mean Reward: 0.548. Std of Reward: 0.049. Training.
# [INFO] OctagonAgentSolo. Step: 2180000. Time Elapsed: 4230.271 s. Mean Reward: 0.551. Std of Reward: 0.055. Training.
# [INFO] OctagonAgentSolo. Step: 2200000. Time Elapsed: 4269.236 s. Mean Reward: 0.541. Std of Reward: 0.054. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2199950.onnx
# [INFO] OctagonAgentSolo. Step: 2220000. Time Elapsed: 4308.299 s. Mean Reward: 0.543. Std of Reward: 0.053. Training.
# [INFO] OctagonAgentSolo. Step: 2240000. Time Elapsed: 4346.664 s. Mean Reward: 0.542. Std of Reward: 0.055. Training.
# [INFO] OctagonAgentSolo. Step: 2260000. Time Elapsed: 4385.374 s. Mean Reward: 0.558. Std of Reward: 0.049. Training.
# [INFO] OctagonAgentSolo. Step: 2280000. Time Elapsed: 4424.272 s. Mean Reward: 0.545. Std of Reward: 0.054. Training.
# [INFO] OctagonAgentSolo. Step: 2300000. Time Elapsed: 4462.116 s. Mean Reward: 0.537. Std of Reward: 0.041. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2299898.onnx
# [INFO] OctagonAgentSolo. Step: 2320000. Time Elapsed: 4500.689 s. Mean Reward: 0.547. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 2340000. Time Elapsed: 4539.112 s. Mean Reward: 0.536. Std of Reward: 0.052. Training.
# [INFO] OctagonAgentSolo. Step: 2360000. Time Elapsed: 4578.572 s. Mean Reward: 0.540. Std of Reward: 0.056. Training.
# [INFO] OctagonAgentSolo. Step: 2380000. Time Elapsed: 4617.651 s. Mean Reward: 0.544. Std of Reward: 0.051. Training.
# [INFO] OctagonAgentSolo. Step: 2400000. Time Elapsed: 4656.438 s. Mean Reward: 0.548. Std of Reward: 0.054. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2399962.onnx
# [INFO] OctagonAgentSolo. Step: 2420000. Time Elapsed: 4695.559 s. Mean Reward: 0.551. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 2440000. Time Elapsed: 4735.410 s. Mean Reward: 0.537. Std of Reward: 0.055. Training.
# [INFO] OctagonAgentSolo. Step: 2460000. Time Elapsed: 4773.899 s. Mean Reward: 0.543. Std of Reward: 0.051. Training.
# [INFO] OctagonAgentSolo. Step: 2480000. Time Elapsed: 4812.410 s. Mean Reward: 0.548. Std of Reward: 0.049. Training.
# [INFO] OctagonAgentSolo. Step: 2500000. Time Elapsed: 4851.433 s. Mean Reward: 0.541. Std of Reward: 0.049. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2499904.onnx
# [INFO] OctagonAgentSolo. Step: 2520000. Time Elapsed: 4890.258 s. Mean Reward: 0.541. Std of Reward: 0.053. Training.
# [INFO] OctagonAgentSolo. Step: 2540000. Time Elapsed: 4929.043 s. Mean Reward: 0.566. Std of Reward: 0.051. Training.
# [INFO] OctagonAgentSolo. Step: 2560000. Time Elapsed: 4968.958 s. Mean Reward: 0.540. Std of Reward: 0.050. Training.
# [INFO] OctagonAgentSolo. Step: 2580000. Time Elapsed: 5007.567 s. Mean Reward: 0.536. Std of Reward: 0.051. Training.
# [INFO] OctagonAgentSolo. Step: 2600000. Time Elapsed: 5046.939 s. Mean Reward: 0.561. Std of Reward: 0.049. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2599920.onnx
# [INFO] OctagonAgentSolo. Step: 2620000. Time Elapsed: 5085.914 s. Mean Reward: 0.555. Std of Reward: 0.044. Training.
# [INFO] OctagonAgentSolo. Step: 2640000. Time Elapsed: 5124.550 s. Mean Reward: 0.541. Std of Reward: 0.049. Training.
# [INFO] OctagonAgentSolo. Step: 2660000. Time Elapsed: 5162.737 s. Mean Reward: 0.553. Std of Reward: 0.047. Training.
# [INFO] OctagonAgentSolo. Step: 2680000. Time Elapsed: 5201.601 s. Mean Reward: 0.564. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 2700000. Time Elapsed: 5240.248 s. Mean Reward: 0.551. Std of Reward: 0.051. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2699991.onnx
# [INFO] OctagonAgentSolo. Step: 2720000. Time Elapsed: 5278.989 s. Mean Reward: 0.554. Std of Reward: 0.037. Training.
# [INFO] OctagonAgentSolo. Step: 2740000. Time Elapsed: 5317.631 s. Mean Reward: 0.545. Std of Reward: 0.053. Training.
# [INFO] OctagonAgentSolo. Step: 2760000. Time Elapsed: 5355.549 s. Mean Reward: 0.546. Std of Reward: 0.056. Training.
# [INFO] OctagonAgentSolo. Step: 2780000. Time Elapsed: 5394.843 s. Mean Reward: 0.532. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 2800000. Time Elapsed: 5433.655 s. Mean Reward: 0.558. Std of Reward: 0.041. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2799975.onnx
# [INFO] OctagonAgentSolo. Step: 2820000. Time Elapsed: 5473.271 s. Mean Reward: 0.546. Std of Reward: 0.053. Training.
# [INFO] OctagonAgentSolo. Step: 2840000. Time Elapsed: 5512.269 s. Mean Reward: 0.541. Std of Reward: 0.050. Training.
# [INFO] OctagonAgentSolo. Step: 2860000. Time Elapsed: 5550.807 s. Mean Reward: 0.551. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 2880000. Time Elapsed: 5589.646 s. Mean Reward: 0.544. Std of Reward: 0.043. Training.
# [INFO] OctagonAgentSolo. Step: 2900000. Time Elapsed: 5628.222 s. Mean Reward: 0.531. Std of Reward: 0.050. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2899956.onnx
# [INFO] OctagonAgentSolo. Step: 2920000. Time Elapsed: 5666.998 s. Mean Reward: 0.540. Std of Reward: 0.046. Training.
# [INFO] OctagonAgentSolo. Step: 2940000. Time Elapsed: 5705.206 s. Mean Reward: 0.547. Std of Reward: 0.047. Training.
# [INFO] OctagonAgentSolo. Step: 2960000. Time Elapsed: 5744.349 s. Mean Reward: 0.541. Std of Reward: 0.043. Training.
# [INFO] OctagonAgentSolo. Step: 2980000. Time Elapsed: 5783.475 s. Mean Reward: 0.542. Std of Reward: 0.048. Training.
# [INFO] OctagonAgentSolo. Step: 3000000. Time Elapsed: 5822.825 s. Mean Reward: 0.546. Std of Reward: 0.045. Training.
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-2999885.onnx
# [INFO] Exported results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-3000141.onnx
# [INFO] Copied results/260518_0016/OctagonAgentSolo/OctagonAgentSolo-3000141.onnx to results/260518_0016/OctagonAgentSolo.onnx.

# %% [markdown]
# ### Sequential training runs with yaml injections

# %% [markdown]
# ### Sequential inference runs
# - across a list of input directory names, or all directories in the run_dir
# - output_dir can be a separate sim directory in results

# %%
#solo
from batch_inference_func import batch_inference
batch_inference(
    run_dir=Path("~/Unity/Octagon").expanduser(),
    unity_env_path=Path("/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64"), # This build has 145 trials correctly removed
    # patched_yaml_path=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfig.yaml").expanduser(),
    patched_yaml_path=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml").expanduser(),
    out_root=Path("~/Unity/Octagon/simulations").expanduser(),
    episodes=201,
    timeout_s=5000,
    seed=17,
    results_subdir="2605/260515",
    run_ids=[f"260515_{i:04d}" for i in range(31, 41)],
)
# Out:
# Found 10 models to run inference on: ['260515_0031', '260515_0032', '260515_0033', '260515_0034', '260515_0035', '260515_0036', '260515_0037', '260515_0038', '260515_0039', '260515_0040']
#
# === [1/10] Running inference: 260515_0031 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0031', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0031', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0031 -> /home/tom/Unity/Octagon/simulations/260515_0031/mlagents_stdout.log ===
#
# === [2/10] Running inference: 260515_0032 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0032', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0032', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0032 -> /home/tom/Unity/Octagon/simulations/260515_0032/mlagents_stdout.log ===
#
# === [3/10] Running inference: 260515_0033 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0033', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0033', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0033 -> /home/tom/Unity/Octagon/simulations/260515_0033/mlagents_stdout.log ===
#
# === [4/10] Running inference: 260515_0034 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0034', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0034', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0034 -> /home/tom/Unity/Octagon/simulations/260515_0034/mlagents_stdout.log ===
#
# === [5/10] Running inference: 260515_0035 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0035', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0035', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0035 -> /home/tom/Unity/Octagon/simulations/260515_0035/mlagents_stdout.log ===
#
# === [6/10] Running inference: 260515_0036 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0036', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0036', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0036 -> /home/tom/Unity/Octagon/simulations/260515_0036/mlagents_stdout.log ===
#
# === [7/10] Running inference: 260515_0037 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0037', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0037', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0037 -> /home/tom/Unity/Octagon/simulations/260515_0037/mlagents_stdout.log ===
#
# === [8/10] Running inference: 260515_0038 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0038', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0038', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0038 -> /home/tom/Unity/Octagon/simulations/260515_0038/mlagents_stdout.log ===
#
# === [9/10] Running inference: 260515_0039 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0039', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0039', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0039 -> /home/tom/Unity/Octagon/simulations/260515_0039/mlagents_stdout.log ===
#
# === [10/10] Running inference: 260515_0040 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfigHigherRnd.yaml', '--run-id', '2605/260515/260515_0040', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0040', '--sim_eps', '201', '--seed', '17']
# === Finished: 260515_0040 -> /home/tom/Unity/Octagon/simulations/260515_0040/mlagents_stdout.log ===
# {'260515_0031': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0031/mlagents_stdout.log'),
#  '260515_0032': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0032/mlagents_stdout.log'),
#  '260515_0033': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0033/mlagents_stdout.log'),
#  '260515_0034': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0034/mlagents_stdout.log'),
#  '260515_0035': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0035/mlagents_stdout.log'),
#  '260515_0036': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0036/mlagents_stdout.log'),
#  '260515_0037': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0037/mlagents_stdout.log'),
#  '260515_0038': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0038/mlagents_stdout.log'),
#  '260515_0039': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0039/mlagents_stdout.log'),
#  '260515_0040': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0040/mlagents_stdout.log')}

# %%
# testing cell, short inference run of 1 model
from batch_inference_func import batch_inference
batch_inference(
    run_dir=Path("~/Unity/Octagon").expanduser(),
    unity_env_path=Path("/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64"),
    patched_yaml_path=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfig.yaml").expanduser(),
    out_root=Path("~/Unity/Octagon/simulations").expanduser(),
    episodes=10,
    timeout_s=600,
    seed=17,
    results_subdir="2605/260515",
    run_ids=["260515_0001"],
)
# Out:
# Found 1 models to run inference on: ['260515_0001']
#
# === [1/1] Running inference: 260515_0001 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SoloConfig.yaml', '--run-id', '2605/260515/260515_0001', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260515_04_solo.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/260515_0001', '--sim_eps', '10', '--seed', '17']
# === Finished: 260515_0001 -> /home/tom/Unity/Octagon/simulations/260515_0001/mlagents_stdout.log ===
# {'260515_0001': PosixPath('/home/tom/Unity/Octagon/simulations/260515_0001/mlagents_stdout.log')}

# %%
#social (note that only the build and .yaml dictate solo/social difference)
from batch_inference_func import batch_inference
batch_inference(
    run_dir=Path("~/Unity/Octagon").expanduser(),
    unity_env_path=Path("/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64"), 
    patched_yaml_path=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml").expanduser(),
    trial_seq=Path("~/repos/agent_training/trial_sequences/trials_100000_seed17.json").expanduser(),
    out_root=Path("~/Unity/Octagon/simulations").expanduser(),
    episodes=201,
    timeout_s=5000,
    seed=17,
    results_subdir="2606/260624",
    run_ids=[f"260624_{i:04d}" for i in range(31, 41)],
)
# Out:
# Found 10 models to run inference on: ['260624_0031', '260624_0032', '260624_0033', '260624_0034', '260624_0035', '260624_0036', '260624_0037', '260624_0038', '260624_0039', '260624_0040']
#
# === [1/10] Running inference: 260624_0031 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0031', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0031', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0031 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0031/mlagents_stdout.log ===
#
# === [2/10] Running inference: 260624_0032 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0032', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0032', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0032 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0032/mlagents_stdout.log ===
#
# === [3/10] Running inference: 260624_0033 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0033', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0033', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0033 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0033/mlagents_stdout.log ===
#
# === [4/10] Running inference: 260624_0034 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0034', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0034', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0034 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0034/mlagents_stdout.log ===
#
# === [5/10] Running inference: 260624_0035 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0035', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0035', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0035 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0035/mlagents_stdout.log ===
#
# === [6/10] Running inference: 260624_0036 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0036', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0036', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0036 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0036/mlagents_stdout.log ===
#
# === [7/10] Running inference: 260624_0037 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0037', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0037', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0037 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0037/mlagents_stdout.log ===
#
# === [8/10] Running inference: 260624_0038 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0038', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0038', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0038 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0038/mlagents_stdout.log ===
#
# === [9/10] Running inference: 260624_0039 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0039', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0039', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0039 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0039/mlagents_stdout.log ===
#
# === [10/10] Running inference: 260624_0040 ===
# ['mlagents-learn', '/home/tom/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml', '--run-id', '2606/260624/260624_0040', '--resume', '--inference', '--base-port', '5015', '--env', '/home/tom/Unity/Octagon/builds/build_260708_01_social.x86_64', '--no-graphics', '--env-args', '--sim_out', '/home/tom/Unity/Octagon/simulations/2606/260624/260624_0040', '--sim_eps', '201', '--trial_seq', '/home/tom/repos/agent_training/trial_sequences/trials_100000_seed17.json', '--seed', '17']
# === Finished: 260624_0040 -> /home/tom/Unity/Octagon/simulations/2606/260624/260624_0040/mlagents_stdout.log ===
# {'260624_0031': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0031/mlagents_stdout.log'),
#  '260624_0032': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0032/mlagents_stdout.log'),
#  '260624_0033': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0033/mlagents_stdout.log'),
#  '260624_0034': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0034/mlagents_stdout.log'),
#  '260624_0035': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0035/mlagents_stdout.log'),
#  '260624_0036': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0036/mlagents_stdout.log'),
#  '260624_0037': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0037/mlagents_stdout.log'),
#  '260624_0038': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0038/mlagents_stdout.log'),
#  '260624_0039': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0039/mlagents_stdout.log'),
#  '260624_0040': PosixPath('/home/tom/Unity/Octagon/simulations/2606/260624/260624_0040/mlagents_stdout.log')}
