# %%
from trainer_and_simulator_functions import sequential_runs
from pathlib import Path

# %% [markdown]
# ### Sequential training runs without yaml injection or simulation functionality

# %%
sequential_runs(
        in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml").expanduser(),
        run_dir=Path("~/Unity/Octagon").expanduser(),
        gamma=0.99,
        sp=1e-3,
        behaviour_name="OctagonAgentSocial",
        unity_build=Path("/home/tom/Unity/Octagon/builds/build_260408_02.x86_64"),
        base_run_id="260415",
        device="cuda:0",
        n_models=10,
        run_id_offset=0,
        simulate=False,
        n_envs=16,
        seed=None,
        # extra_args=["--resume"]
)
# Out:
# patched yaml for run 260415_0000 with gamma=0.99 and step_penalty=0.001 to /home/tom/Unity/Octagon/SocialConfig.yaml
# launching training for run 260415_0000 with config /home/tom/Unity/Octagon/SocialConfig.yaml
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sequential_runs(
#       2         in_yaml=Path("~/Unity/Octagon/Assets/Scripts/MLConfigFiles/SocialConfig.yaml").expanduser(),
#       3         run_dir=Path("~/Unity/Octagon").expanduser(),
#       4         gamma=0.99,
#       5         sp=1e-3,
#       6         behaviour_name="OctagonAgentSocial",
#       7         unity_build=Path("/home/tom/Unity/Octagon/builds/build_260408_02.x86_64"),
#       8         base_run_id="260415",
#       9         device="cuda:0",
#      10         n_models=10,
#      11         run_id_offset=0,
#      12         simulate=False,
#      13         n_envs=16,
#      14         seed=None,
#      15         # extra_args=["--resume"]
#      16 )
#
# File ~/repos/agent_training/trainer_and_simulator_functions.py:427, in sequential_runs(in_yaml, run_dir, yaml_injection, gamma, sp, behaviour_name, unity_build, base_run_id, device, n_models, run_id_offset, simulate, n_envs, n_steps, seed, extra_args)
#     425 print(f"launching training for run {run_id} with config {patched_yaml_path}")
#     426 # this function launches one training run with the specified yaml file and Unity environment build
# --> 427 launch_training(
#     428     patched_yaml=patched_yaml_path,
#     429     unity_env_path=unity_build,
#     430     run_id=run_id,
#     431     torch_device=device,
#     432     num_envs=n_envs,
#     433     base_port=train_port,
#     434     seed=seed,
#     435     run_dir=run_dir,
#     436     extra_args=extra_args
#     437 )
#     439 # if simulate == True:
#     440 #     print(f"launching inference for run {run_id}")
#     441 #     # this function launches one inference run using the trained model from the training run
#    (...)
#     460 #         print(f"[WARNING] Simulation failed for {run_id}: {type(e).__name__}: {e}")
#     461 #         print("[WARNING] Continuing to next model.")
#     463 time.sleep(5)
#
# File ~/repos/agent_training/trainer_and_simulator_functions.py:154, in launch_training(patched_yaml, unity_env_path, run_id, torch_device, num_envs, base_port, seed, extra_args, run_dir)
#     151 unity_env_path = Path(unity_env_path)
#     153 if not patched_yaml.exists():
# --> 154     raise FileNotFoundError(f"Patched yaml file not found: {patched_yaml}")
#     155 if not unity_env_path.exists():
#     156     raise FileNotFoundError(f"Unity environment not found: {unity_env_path}")
#
# FileNotFoundError: Patched yaml file not found: /home/tom/Unity/Octagon/SocialConfig.yaml

# %% [markdown]
# ### Sequential training runs with yaml injections
