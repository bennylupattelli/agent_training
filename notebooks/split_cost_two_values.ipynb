# %%
# imports

import numpy as np
import torch
from pathlib import Path
from ruamel.yaml import YAML
yaml = YAML()
yaml.preserve_quotes = True
import subprocess
import shutil
import subprocess, time, os, signal
from pathlib import Path

# %%
# imports
from pathlib import Path
import sys  

# Get my_package directory path from Notebook
parent_dir = str(Path().resolve().parents[0])

# Add to sys.path
sys.path.insert(0, parent_dir)

# %%
import full_simulator_functions as trainer

# %% [markdown]
# pick two values (one high and one low)
#
# e.g., 0.00025 and 0.004 (minimum and maximum of previous theta selection)

# %%
import os
cwd = os.getcwd()

# %%
# for mac

values=(0.00025, 0.004)
N=10
in_yaml = Path("/Users/benny/Repos/octagon/Assets/Scripts/MLConfigFiles/SoloSplitCostConfig.yaml")
work_dir = cwd
unity_build = Path("/Users/benny/swc/agents/builds/split_cost/SoloOctagon260724.app")
behaviour_name = "OctagonAgentSolo"
base_run_id = "two_value_split_cost_test_mac"
device="cpu"
simulate=True
n_envs=2
n_eps=1000

# %%
# for desktop windows

values=(0.00025, 0.004)
N=10
in_yaml=Path("C:/Users/Benedetta/octagon/Assets/Scripts/MLConfigFiles/SoloSplitCostConfig.yaml")
work_dir = cwd
unity_build = Path("C:/Users/Benedetta/Desktop/agents/builds/SoloOctagon260724/Octagon.exe")
behaviour_name = "OctagonAgentSolo"
base_run_id = "two_value_split_cost"
device="cuda"
simulate=True
n_envs=4
n_eps=1000

# %%
trainer.split_cost_simulator_two_values(
    values=values,
    N=N,
    in_yaml=in_yaml,
    work_dir=work_dir,
    behaviour_name=behaviour_name,
    unity_build=unity_build,
    base_run_id=base_run_id,
    device=device,
    simulate=simulate,
    n_envs=n_envs,
    n_eps=n_eps
)
# Out:
# [(0.00025, 0.00025), (0.00025, 0.004), (0.004, 0.00025), (0.004, 0.004)]
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.30.0,
#   ml-agents-envs: 0.30.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.5.1
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784204504.615567 8781826 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784204504.615676 8781824 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Hyperparameters for behavior name OctagonAgentSolo:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	10240
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.01
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	30
# 	checkpoint_interval:	100000
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Parameter 'translation_cost' is in lesson 'translation_cost' and has value 'Float: value=0.00025'.
# [INFO] Parameter 'turning_cost' is in lesson 'turning_cost' and has value 'Float: value=0.00025'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 trainer.split_cost_simulator_two_values(
#       2     values=values,
#       3     N=N,
#       4     in_yaml=in_yaml,
#       5     work_dir=work_dir,
#       6     behaviour_name=behaviour_name,
#       7     unity_build=unity_build,
#       8     base_run_id=base_run_id,
#       9     device=device,
#      10     simulate=simulate,
#      11     n_envs=n_envs,
#      12     n_eps=n_eps
#      13 )
#
# File ~/Repos/agent_training/full_simulator_functions.py:324, in split_cost_simulator_two_values(values, N, in_yaml, work_dir, behaviour_name, unity_build, base_run_id, device, simulate, n_envs, n_eps)
#     316     writer.writerow([
#     317         run_id,
#     318         seed,
#     319         tc,
#     320         rc
#     321     ])
#     323 # this function launches one training run with the specified yaml file and Unity environment build
# --> 324 launch_training(
#     325     patched_yaml=patched_yaml_path,
#     326     unity_env_path=unity_build,
#     327     run_id=run_id,
#     328     torch_device=device,
#     329     num_envs=n_envs,
#     330     base_port=train_port,
#     331     seed=seed,
#     332     cwd=work_dir,
#     333 )
#     335 if simulate:
#     336     # this function launches one inference run using the trained model from the training run
#     337     # specify the number of episodes to run
#     338     # the random seed is not currently implemented in the inference code, but it is included here for future use
#     339     try:
#
# File ~/Repos/agent_training/training_and_eval_process_lauching.py:68, in launch_training(patched_yaml, unity_env_path, run_id, torch_device, num_envs, base_port, seed, extra_args, cwd)
#      60 with subprocess.Popen(
#      61     cmd,
#      62     stdout=subprocess.PIPE,
#    (...)
#      65     cwd=str(cwd) if cwd else None
#      66 ) as p:
#      67     assert p.stdout is not None
# ---> 68     for line in p.stdout:
#      69         print(line, end='')  # print each line as it is received
#      70     p.wait()  # wait for the process to complete
#
# KeyboardInterrupt:
