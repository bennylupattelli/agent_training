# %%
# imports

import numpy as np
import torch
from pathlib import Path
from ruamel.yaml import YAML
yaml = YAML()
yaml.preserve_quotes = True
import subprocess
import shutil
import subprocess, time, os, signal
from pathlib import Path

# %%
import full_simulator_functions as trainer

# %% [markdown]
# ## Tests for split cost agents

# %% [markdown]
# ### Testing theta sampler

# %%
theta = trainer.sample_split_cost(seed=17, n=100)

# %%
len(theta)
# Out:
# 100

# %%
tc, rc = map(float, theta[10])

# %%
tc, rc
# Out:
# (0.0006666666666666666, 0.00025)

# %%
input_split_theta = theta[50::]

# %%
input_split_theta
# Out:
# array([[0.00233333, 0.00025   ],
#        [0.00233333, 0.00066667],
#        [0.00233333, 0.00108333],
#        [0.00233333, 0.0015    ],
#        [0.00233333, 0.00191667],
#        [0.00233333, 0.00233333],
#        [0.00233333, 0.00275   ],
#        [0.00233333, 0.00316667],
#        [0.00233333, 0.00358333],
#        [0.00233333, 0.004     ],
#        [0.00275   , 0.00025   ],
#        [0.00275   , 0.00066667],
#        [0.00275   , 0.00108333],
#        [0.00275   , 0.0015    ],
#        [0.00275   , 0.00191667],
#        [0.00275   , 0.00233333],
#        [0.00275   , 0.00275   ],
#        [0.00275   , 0.00316667],
#        [0.00275   , 0.00358333],
#        [0.00275   , 0.004     ],
#        [0.00316667, 0.00025   ],
#        [0.00316667, 0.00066667],
#        [0.00316667, 0.00108333],
#        [0.00316667, 0.0015    ],
#        [0.00316667, 0.00191667],
#        [0.00316667, 0.00233333],
#        [0.00316667, 0.00275   ],
#        [0.00316667, 0.00316667],
#        [0.00316667, 0.00358333],
#        [0.00316667, 0.004     ],
#        [0.00358333, 0.00025   ],
#        [0.00358333, 0.00066667],
#        [0.00358333, 0.00108333],
#        [0.00358333, 0.0015    ],
#        [0.00358333, 0.00191667],
#        [0.00358333, 0.00233333],
#        [0.00358333, 0.00275   ],
#        [0.00358333, 0.00316667],
#        [0.00358333, 0.00358333],
#        [0.00358333, 0.004     ],
#        [0.004     , 0.00025   ],
#        [0.004     , 0.00066667],
#        [0.004     , 0.00108333],
#        [0.004     , 0.0015    ],
#        [0.004     , 0.00191667],
#        [0.004     , 0.00233333],
#        [0.004     , 0.00275   ],
#        [0.004     , 0.00316667],
#        [0.004     , 0.00358333],
#        [0.004     , 0.004     ]])

# %% [markdown]
# ### Testing full simulator umbrella function with split cost

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# '/Users/benny/Repos/agent_training'

# %%
in_yaml = Path("/Users/benny/Repos/octagon/Assets/Scripts/MLConfigFiles/SoloSplitCostConfig.yaml")
work_dir = cwd
unity_env_path = Path("/Users/benny/Documents/swc/agents/builds/split_cost/SoloOctagon260724.app")
step_penalty = False
split_penalty = True
behaviour_name = "OctagonAgentSolo"
n = 100
seed = 17
base_run_id = "split_cost_test_mac"

# %%
trainer.sbi_simulator(
    n = 100,
    in_yaml = in_yaml,
    work_dir = work_dir,
    unity_build = unity_env_path,
    base_run_id = "split_cost_test_mac",
    device = "cpu",
    simulate = True,
    n_envs = 2,
    n_eps = n,
    seed=seed,
    split_penalty=split_penalty
)
# Out:
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.30.0,
#   ml-agents-envs: 0.30.0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.5.1
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# /opt/miniconda3/envs/mlagents/lib/python3.10/site-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782406063.010195 19368217 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782406063.046423 19368215 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected to Unity environment with package version 3.0.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [INFO] Connected new brain: OctagonAgentSolo?team=0
# [WARNING] Deleting TensorBoard data events.out.tfevents.1782316951.Benny.79630.0 that was left over from a previous run.
# [INFO] Hyperparameters for behavior name OctagonAgentSolo:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	512
# 	  buffer_size:	10240
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:
# 	    sequence_length:	64
# 	    memory_size:	256
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.01
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	30
# 	checkpoint_interval:	100000
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	20000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Parameter 'translation_cost' is in lesson 'translation_cost' and has value 'Float: value=0.00025'.
# [INFO] Parameter 'turning_cost' is in lesson 'turning_cost' and has value 'Float: value=0.00025'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 trainer.sbi_simulator(
#       2     n = 100,
#       3     in_yaml = in_yaml,
#       4     work_dir = work_dir,
#       5     unity_build = unity_env_path,
#       6     base_run_id = "split_cost_test_mac",
#       7     device = "cpu",
#       8     simulate = True,
#       9     n_envs = 2,
#      10     n_eps = n,
#      11     seed=seed,
#      12     split_penalty=split_penalty
#      13 )
#
# File ~/Repos/agent_training/trainer_and_simulator_functions.py:650, in sbi_simulator(n, in_yaml, work_dir, behaviour_name, unity_build, base_run_id, device, simulate, n_envs, n_eps, seed, step_penalty, split_penalty)
#     638     patch_agents_yaml(
#     639         template_yaml=in_yaml,
#     640         output_yaml=patched_yaml_path,
#    (...)
#     646         extrinsic_reward_key="extrinsic"
#     647     )
#     649 # this function launches one training run with the specified yaml file and Unity environment build
# --> 650 launch_training(
#     651     patched_yaml=patched_yaml_path,
#     652     unity_env_path=unity_build,
#     653     run_id=run_id,
#     654     torch_device=device,
#     655     num_envs=n_envs,
#     656     base_port=train_port,
#     657     seed=seed,
#     658     cwd=work_dir,
#     659 )
#     661 if simulate:
#     662     # this function launches one inference run using the trained model from the training run
#     663     # specify the number of episodes to run
#     664     # the random seed is not currently implemented in the inference code, but it is included here for future use
#     665     try:
#
# File ~/Repos/agent_training/trainer_and_simulator_functions.py:285, in launch_training(patched_yaml, unity_env_path, run_id, torch_device, num_envs, base_port, seed, extra_args, cwd)
#     277 with subprocess.Popen(
#     278     cmd,
#     279     stdout=subprocess.PIPE,
#    (...)
#     282     cwd=str(cwd) if cwd else None
#     283 ) as p:
#     284     assert p.stdout is not None
# --> 285     for line in p.stdout:
#     286         print(line, end='')  # print each line as it is received
#     287     p.wait()  # wait for the process to complete
#
# KeyboardInterrupt:
