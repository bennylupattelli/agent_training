# %%
# imports

import numpy as np
import torch
from pathlib import Path
from ruamel.yaml import YAML
yaml = YAML()
yaml.preserve_quotes = True
import subprocess
import shutil
import subprocess, time, os, signal
from pathlib import Path

# %%
import trainer_and_simulator_functions as trainer

# %%
for id in range(18,36):
    trainer.launch_onnx_inference_sim(
            unity_env_path = Path("C:/Users/Benedetta/Desktop/agents/builds/LoggingFrequencyBuild/Octagon.exe"),
            onnx_model_path = Path("C:/Users/Benedetta/Desktop/agents/data_bundled/models_v2") / f"M{id}.onnx",
            out_path = Path("c:/Users/Benedetta/Desktop/agents/data_bundled/simulation_ext") / f"sim_{id}",
            episodes = 1000,
            timeout_s = 10000,
            seed = 17,
        )
